# %%
#importing library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Reading Data
players = pd.read_csv("C:\\Users\\Thanis\\Desktop\\SuperCleaned.csv")
# Out:
# C:\Users\Thanis\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (101,107,108,140,141,145,146,147,153,154,158,159,160) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
#description of the data
players.describe()
# Out:
#          Unnamed: 0            ID           Age  BATTING_Tests_Mat  \
# count  90308.000000  9.030800e+04  64671.000000        3652.000000
# mean   45153.500000  3.463182e+05     47.592383          15.000000
# std    26069.818392  3.974984e+05     21.750813          23.069388
# min        0.000000  3.931000e+03    -51.000000           1.000000
# 25%    22576.750000  2.851175e+04     29.000000           2.000000
# 50%    45153.500000  5.336650e+04     42.000000           6.000000
# 75%    67730.250000  5.960022e+05     65.000000          17.000000
# max    90307.000000  1.178645e+06    254.000000         200.000000
#
#        BATTING_Tests_Inns  BATTING_Tests_NO  BATTING_Tests_Runs  \
# count         3605.000000       3605.000000         3605.000000
# mean            24.399168          3.188904          635.452982
# std             37.746683          5.741141         1428.712495
# min              1.000000          0.000000            0.000000
# ...

# %%
players.dtypes
# Out:
# Unnamed: 0             int64
# ID                     int64
# NAME                  object
# COUNTRY               object
# Full name             object
#                       ...
# BOWLING_T20s_Econ    float64
# BOWLING_T20s_SR      float64
# BOWLING_T20s_4w      float64
# BOWLING_T20s_5w      float64
# BOWLING_T20s_10      float64
# Length: 177, dtype: object

# %%
players.sample(5)
# Out:
#        Unnamed: 0      ID            NAME                   COUNTRY  \
# 40391       40391   35778    Vaibhav Jain                     India
# 22590       22590  364161   Cameron Mirza  United States of America
# 5071         5071  591150    David Morfee                    Jersey
# 31611       31611   29363       W Hosking                     India
# 43873       43873   41529  Munawwar Ahmed                  Pakistan
#
#             Full name Birthdate              Birthplace     Died  \
# 40391    Vaibhav Jain  22/01/87         Kota, Rajasthan    Alive
# 22590   Cameron Mirza  04/08/93  Morristown, New Jersey    Alive
# 5071     David Morfee  14/02/68                     NaN    Alive
# 31611     W S Hosking       NaN                     NaN  Unknown
# 43873  Munawwar Ahmed       NaN                     NaN  Unknown
#
#       Date_of_death   Age  ... BOWLING_T20s_Runs BOWLING_T20s_Wkts  \
# 40391           NaN  32.0  ...               NaN               NaN
# ...

# %%
#List of column names
list(players.columns)
# Out:
# ['Unnamed: 0',
#  'ID',
#  'NAME',
#  'COUNTRY',
#  'Full name',
#  'Birthdate',
#  'Birthplace',
#  'Died',
#  'Date_of_death',
#  'Age',
#  'Major teams',
#  'Batting style',
#  'Bowling style',
#  'Other',
#  'AWARDS',
#  'BATTING_Tests_Mat',
#  'BATTING_Tests_Inns',
#  'BATTING_Tests_NO',
#  'BATTING_Tests_Runs',
#  'BATTING_Tests_HS',
#  'BATTING_Tests_Ave',
#  'BATTING_Tests_BF',
#  'BATTING_Tests_SR',
#  'BATTING_Tests_100',
#  'BATTING_Tests_50',
#  'BATTING_Tests_4s',
#  'BATTING_Tests_6s',
#  'BATTING_Tests_Ct',
#  'BATTING_Tests_St',
#  'BATTING_ODIs_Mat',
#  'BATTING_ODIs_Inns',
#  'BATTING_ODIs_NO',
#  'BATTING_ODIs_Runs',
#  'BATTING_ODIs_HS',
#  'BATTING_ODIs_Ave',
#  'BATTING_ODIs_BF',
#  'BATTING_ODIs_SR',
#  'BATTING_ODIs_100',
#  'BATTING_ODIs_50',
#  'BATTING_ODIs_4s',
#  'BATTING_ODIs_6s',
#  'BATTING_ODIs_Ct',
#  'BATTING_ODIs_St',
#  'BATTING_T20Is_Mat',
#  'BATTING_T20Is_Inns',
#  'BATTING_T20Is_NO',
#  'BATTING_T20Is_Runs',
#  'BATTING_T20Is_HS',
# ...

# %%
#Size of the data
players.shape
# Out:
# (90308, 177)

# %%
#Finding number of missing values
players.isnull().sum()
# Out:
# Unnamed: 0               0
# ID                       0
# NAME                     2
# COUNTRY                  0
# Full name                2
#                      ...
# BOWLING_T20s_Econ    85259
# BOWLING_T20s_SR      86060
# BOWLING_T20s_4w      85258
# BOWLING_T20s_5w      85258
# BOWLING_T20s_10      85258
# Length: 177, dtype: int64

# %%
x = players.isnull().sum()
x.plot(kind='barh')
plt.figure(figsize=(30,20))
plt.show()

# %%
#In Other variable Nan or missed value are the only players list and remaining are from administrations, Coaches, Umpires etc
players.Other.unique()
# Out:
# array([nan, 'Coach, Administrator', 'Umpire', 'Umpire, Referee',
#        'Umpire, Coach', 'Administrator', 'Referee', 'Scorer', 'Coach',
#        'Selector', 'Commentator', 'Umpire, Commentator',
#        'Umpire, Coach, Commentator, Journalist, Author',
#        'Physiotherapist', 'Umpire, Author, Scorer',
#        'Commentator, Journalist, Author', 'Commentator, Journalist',
#        'Author', 'Coach, Administrator, Author', 'Umpire, Scorer',
#        'Referee, Administrator', 'Umpire, Administrator, Scorer',
#        'Umpire, Administrator', 'Referee, Coach',
#        'Administrator, Selector', 'Coach, Commentator', 'Journalist',
#        'Referee, Coach, Administrator, Commentator',
#        'Administrator, Commentator', 'Umpire, Administrator, Selector',
#        'Referee, Commentator', 'Umpire, Referee, Administrator',
#        'Coach, Commentator, Selector', 'Umpire, Coach, Journalist',
#        'Coach, Commentator, Journalist, Author', 'Umpire, Referee, Coach',
# ...

# %%
#total number of players
players.Other.isnull().sum()
# Out:
# 83664

# %%
#filling nan with zeros
players.Other.fillna(0, inplace = True)

# %%
#Considering only the international ODI's and T20's batting and bowling variables into account
players1 = players[['NAME',
         'COUNTRY',
         'Died',
         'Age',
         'Other',
         'Major teams',
         'Batting style',
         'Bowling style',
         'BATTING_ODIs_Mat',
         'BATTING_ODIs_Inns',
         'BATTING_ODIs_NO',
         'BATTING_ODIs_Runs',
         'BATTING_ODIs_Ave',
         'BATTING_ODIs_BF',
         'BATTING_ODIs_SR',
         'BATTING_ODIs_100',
         'BATTING_ODIs_50',
         'BATTING_T20Is_Mat',
         'BATTING_T20Is_Inns',
         'BATTING_T20Is_NO',
         'BATTING_T20Is_Runs',
         'BATTING_T20Is_Ave',
         'BATTING_T20Is_BF',
         'BATTING_T20Is_SR',
         'BATTING_T20Is_100',
         'BATTING_T20Is_50',
         'BOWLING_ODIs_Mat',
         'BOWLING_ODIs_Inns',
         'BOWLING_ODIs_Balls',
         'BOWLING_ODIs_Runs',
         'BOWLING_ODIs_Wkts',
         'BOWLING_ODIs_Ave',
         'BOWLING_ODIs_Econ',
         'BOWLING_ODIs_SR',
         'BOWLING_ODIs_4w',
         'BOWLING_ODIs_5w',
         'BOWLING_T20Is_Mat',
         'BOWLING_T20Is_Inns',
         'BOWLING_T20Is_Balls',
         'BOWLING_T20Is_Runs',
         'BOWLING_T20Is_Wkts',
         'BOWLING_T20Is_Ave',
         'BOWLING_T20Is_Econ',
         'BOWLING_T20Is_SR',
         'BOWLING_T20Is_4w',
         'BOWLING_T20Is_5w',]]

# %%
players1['Batting style'].isnull().sum()/len(players)*100

# %%
#finding the unique batting style
players1['Batting style'].unique()
# Out:
# array(['Right-hand bat', 'Left-hand bat', nan,
#        'Right-hand bat, Right-hand bat'], dtype=object)

# %%
players1['Batting style'].isna().sum()
# Out:
# 33056

# %%
#dropping the entire row if no data is present in batting style
players1 = players1.dropna(subset = ['Batting style'])

# %%
#Encoding Righthand batsman and lefthand batsmans as 1's and 0's
players1.loc[players1['Batting style'] == 'Right-hand bat, Right-hand bat','Batting style encoded'] = 1
players1.loc[players1['Batting style'] == 'Right-hand bat','Batting style encoded'] = 1
players1.loc[players1['Batting style'] == 'Left-hand bat','Batting style encoded'] = 0

# %%
players1 = players1.astype({"Batting style encoded" : "float64"})

# %%
#Checking no of lef and right hand batsmans
players1['Batting style encoded'].value_counts()
# Out:
# 1.0    47625
# 0.0     9627
# Name: Batting style encoded, dtype: int64

# %%
#finding the unique bowling style
players1['Bowling style'].unique()
# Out:
# array([nan, 'Left-arm bowler (underarm)', 'Right-arm medium',
#        'Right-arm medium-fast', 'Right-arm fast-medium', 'Legbreak',
#        'Right-arm offbreak', 'Slow left-arm orthodox', 'Legbreak googly',
#        'Right-arm slow', 'Right-arm bowler', 'Left-arm medium-fast',
#        'Left-arm medium', 'Right-arm fast', 'Left-arm fast',
#        'Left-arm fast-medium', 'Left-arm slow-medium',
#        'Right-arm medium, Right-arm offbreak', 'Right-arm slow-medium',
#        'Right-arm fast, Right-arm slow (roundarm)',
#        'Right-arm fast (roundarm)', 'Left-arm bowler',
#        'Right-arm slow (underarm)', 'Right-arm offbreak, Legbreak googly',
#        'Left-arm fast (roundarm)', 'Right-arm slow (roundarm)',
#        'Right-arm fast, Right-arm medium',
#        ' (underarm), Right-arm medium',
#        'Right-arm fast-medium (roundarm)',
#        'Right-arm bowler (underarm), Left-arm bowler (underarm)',
# ...

# %%
players1['Bowling style'].isna().sum()
# Out:
# 0

# %%
#dropping the entire row if no data is present in bowling style
players1.dropna(subset = ['Bowling style'], inplace = True)

# %%
#dropping the entire row if the bowling style is unknown
for index, row in players1.iterrows():
    if 'unknown' in row['Bowling style']:
        players1.drop(index, inplace = True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
number = LabelEncoder()

# %%
#label encoder to encode the bowling style
players1['Bowling style encoded'] = number.fit_transform(players1['Bowling style'].astype('str'))

# %% [markdown]
# ### Since the Gender field is not available. We need to extract the gender from the 'major teams' based on the whether it is a mens or womens team

# %%
players1['Major teams'].isna().sum()
# Out:
# 764

# %%
players1.dropna(subset = ['Major teams'], inplace =True)

# %%
#0 for male and 1 for female
players1['Gender'] = 0
for index, row in players1.iterrows():
    if 'Women' in row['Major teams']:
        players1.loc[index,['Gender']] = 1

# %%
players1.Gender.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
#checking the missing values
players1.isnull().sum()
# Out:
# NAME                         0
# COUNTRY                      0
# Died                         0
# Age                       1908
# Other                        0
# Major teams                  0
# Batting style                0
# Bowling style                0
# BATTING_ODIs_Mat         39162
# BATTING_ODIs_Inns        39273
# BATTING_ODIs_NO          39273
# BATTING_ODIs_Runs        39273
# BATTING_ODIs_Ave         39401
# BATTING_ODIs_BF          39544
# BATTING_ODIs_SR          39553
# BATTING_ODIs_100         39273
# BATTING_ODIs_50          39273
# BATTING_T20Is_Mat        40391
# BATTING_T20Is_Inns       40557
# BATTING_T20Is_NO         40557
# BATTING_T20Is_Runs       40557
# BATTING_T20Is_Ave        40712
# BATTING_T20Is_BF         40571
# BATTING_T20Is_SR         40589
# BATTING_T20Is_100        40557
# BATTING_T20Is_50         40557
# BOWLING_ODIs_Mat         39162
# BOWLING_ODIs_Inns        39685
# BOWLING_ODIs_Balls       39685
# BOWLING_ODIs_Runs        39685
# ...

# %% [markdown]
# ### considering only the players who have played atleast one ODI

# %%
#dropping all the players who hasnt played a single ODI
players1.dropna(subset = ['BATTING_ODIs_Mat'], inplace = True)

# %%
#filling all the missed cells with 0's
players1.fillna(0, inplace = True)

# %%
#checking for any missed values
players1.isnull().sum()
# Out:
# NAME                     0
# COUNTRY                  0
# Died                     0
# Age                      0
# Other                    0
# Major teams              0
# Batting style            0
# Bowling style            0
# BATTING_ODIs_Mat         0
# BATTING_ODIs_Inns        0
# BATTING_ODIs_NO          0
# BATTING_ODIs_Runs        0
# BATTING_ODIs_Ave         0
# BATTING_ODIs_BF          0
# BATTING_ODIs_SR          0
# BATTING_ODIs_100         0
# BATTING_ODIs_50          0
# BATTING_T20Is_Mat        0
# BATTING_T20Is_Inns       0
# BATTING_T20Is_NO         0
# BATTING_T20Is_Runs       0
# BATTING_T20Is_Ave        0
# BATTING_T20Is_BF         0
# BATTING_T20Is_SR         0
# BATTING_T20Is_100        0
# BATTING_T20Is_50         0
# BOWLING_ODIs_Mat         0
# BOWLING_ODIs_Inns        0
# BOWLING_ODIs_Balls       0
# BOWLING_ODIs_Runs        0
# BOWLING_ODIs_Wkts        0
# BOWLING_ODIs_Ave         0
# BOWLING_ODIs_Econ        0
# BOWLING_ODIs_SR          0
# ...

# %%
#filtering players only those who are alive and age between 15 and 45
players1 = players1.loc[(players1.Died == 'Alive')  & (players1.Age >= 15) & (players1.Age <= 45) & (players1.Other == 0) ,]

# %%
players1.shape
# Out:
# (1768, 49)

# %%
#Considering only the int and float field before doing a cluster
players2 = players1[[
         'Age',
         'Gender',
         'Batting style encoded',
         'Bowling style encoded',
         'BATTING_ODIs_Mat',
         'BATTING_ODIs_Inns',
         'BATTING_ODIs_NO',
         'BATTING_ODIs_Runs',
         'BATTING_ODIs_Ave',
         'BATTING_ODIs_BF',
         'BATTING_ODIs_SR',
         'BATTING_ODIs_100',
         'BATTING_ODIs_50',
         'BATTING_T20Is_Mat',
         'BATTING_T20Is_Inns',
         'BATTING_T20Is_NO',
         'BATTING_T20Is_Runs',
         'BATTING_T20Is_Ave',
         'BATTING_T20Is_BF',
         'BATTING_T20Is_SR',
         'BATTING_T20Is_100',
         'BATTING_T20Is_50',
         'BOWLING_ODIs_Mat',
         'BOWLING_ODIs_Inns',
         'BOWLING_ODIs_Balls',
         'BOWLING_ODIs_Runs',
         'BOWLING_ODIs_Wkts',
         'BOWLING_ODIs_Ave',
         'BOWLING_ODIs_Econ',
         'BOWLING_ODIs_SR',
         'BOWLING_ODIs_4w',
         'BOWLING_ODIs_5w',
         'BOWLING_T20Is_Mat',
         'BOWLING_T20Is_Inns',
         'BOWLING_T20Is_Balls',
         'BOWLING_T20Is_Runs',
         'BOWLING_T20Is_Wkts',
         'BOWLING_T20Is_Ave',
         'BOWLING_T20Is_Econ',
         'BOWLING_T20Is_SR',
         'BOWLING_T20Is_4w',
         'BOWLING_T20Is_5w']]

# %%
players2.sample(5)
# Out:
#         Age  Gender  Batting style encoded  Bowling style encoded  \
# 44728  32.0       1                    1.0                     85
# 41966  32.0       0                    1.0                     60
# 20656  25.0       0                    1.0                     92
# 87860  37.0       0                    1.0                     92
# 11252  23.0       0                    1.0                     92
#
#        BATTING_ODIs_Mat  BATTING_ODIs_Inns  BATTING_ODIs_NO  \
# 44728              36.0               32.0              3.0
# 41966              75.0               24.0             14.0
# 20656               1.0                0.0              0.0
# 87860               5.0                5.0              0.0
# 11252               5.0                2.0              0.0
#
#        BATTING_ODIs_Runs  BATTING_ODIs_Ave  BATTING_ODIs_BF  ...  \
# 44728              436.0             15.03            845.0  ...
# 41966               79.0              7.90            134.0  ...
# ...

# %%
import matplotlib.pyplot as plt
import scipy
from scipy.cluster.hierarchy import dendrogram,linkage
from sklearn.preprocessing import StandardScaler

# %%
players3 = players2.apply(lambda x : (x- np.mean(x))/ np.std(x))

# %%
from sklearn.cluster import KMeans

# %%
players4 = players3.copy()

# %%
# calculating within group SSE for diff cluster solutions
inertias = []
for k in [10,25,50,100,150,200,250,300]:
    km = KMeans(n_clusters = k, n_init = 10)
    inertia = km.fit(players4).inertia_
    inertias.append(inertia)

    
# plotting scree plot
plt.plot([10,25,50,100,150,200,250,300],inertias)
plt.show()

# %%
# calculating within group SSE for diff cluster solutions without standardizing
inertias = []
for k in [10,25,50,100,150,200,250,300]:
    km = KMeans(n_clusters = k, n_init = 10)
    inertia = km.fit(players2).inertia_
    inertias.append(inertia)

    
# plotting scree plot
plt.plot([10,25,50,100,150,200,250,300],inertias)
plt.show()

# %%
km = KMeans(n_clusters = 100, n_init = 10)
km.fit(players4)
# Out:
# KMeans(n_clusters=100)

# %%
players2['group'] = km.labels_
# Out:
# <ipython-input-48-a42ab29a283b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   players2['group'] = km.labels_

# %%
players2['NAME'] = players1['NAME']
players2['COUNTRY'] = players1['COUNTRY']
# Out:
# <ipython-input-49-2b1200d12425>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   players2['NAME'] = players1['NAME']
# <ipython-input-49-2b1200d12425>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   players2['COUNTRY'] = players1['COUNTRY']

# %%
players2
# Out:
#         Age  Gender  Batting style encoded  Bowling style encoded  \
# 299    30.0       0                    1.0                     85
# 308    39.0       0                    1.0                     60
# 316    34.0       0                    1.0                     36
# 331    31.0       0                    1.0                     60
# 333    29.0       0                    1.0                     36
# ...     ...     ...                    ...                    ...
# 90189  34.0       0                    1.0                     85
# 90231  30.0       1                    1.0                     70
# 90234  29.0       1                    1.0                     85
# 90262  39.0       0                    1.0                     36
# 90287  38.0       0                    1.0                     92
#
#        BATTING_ODIs_Mat  BATTING_ODIs_Inns  BATTING_ODIs_NO  \
# 299                12.0                8.0              3.0
# ...

# %%
Male_list = players2.loc[players2.Gender == 0,]
Female_list = players2.loc[players2.Gender == 1,]

# %%
Male_list
# Out:
#         Age  Gender  Batting style encoded  Bowling style encoded  \
# 299    30.0       0                    1.0                     85
# 308    39.0       0                    1.0                     60
# 316    34.0       0                    1.0                     36
# 331    31.0       0                    1.0                     60
# 333    29.0       0                    1.0                     36
# ...     ...     ...                    ...                    ...
# 90132  38.0       0                    0.0                     92
# 90133  36.0       0                    1.0                     70
# 90189  34.0       0                    1.0                     85
# 90262  39.0       0                    1.0                     36
# 90287  38.0       0                    1.0                     92
#
#        BATTING_ODIs_Mat  BATTING_ODIs_Inns  BATTING_ODIs_NO  \
# 299                12.0                8.0              3.0
# ...

# %%
players2.to_csv('C:\\Users\\Thanis\\Desktop\\clustered_players.csv', index=False)
Male_list.to_csv('C:\\Users\\Thanis\\Desktop\\Male_clustered_players.csv', index=False)
Female_list.to_csv('C:\\Users\\Thanis\\Desktop\\Female_clustered_players.csv', index=False)

# %%
number.inverse_transform(players2.loc[:,['Bowling style encoded']])
# Out:
# C:\Users\Thanis\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# array(['Right-arm medium-fast', 'Right-arm fast-medium', 'Legbreak', ...,
#        'Right-arm medium-fast', 'Legbreak', 'Right-arm offbreak'],
#       dtype=object)

# %%
j = players2.copy()

# %%
j.loc[:,['Bowling style encoded']] = number.inverse_transform(players2.loc[:,['Bowling style encoded']])

# %%
j.sample(10)
# Out:
#         Age  Gender  Batting style encoded  Bowling style encoded  \
# 46998  30.0       0                    0.0       Right-arm medium
# 86254  35.0       1                    1.0     Right-arm offbreak
# 77068  39.0       1                    1.0       Right-arm medium
# 40300  20.0       1                    1.0       Right-arm medium
# 12417  37.0       0                    1.0       Right-arm medium
# 36800  32.0       0                    1.0     Right-arm offbreak
# 1935   30.0       0                    1.0  Right-arm fast-medium
# 75211  45.0       0                    1.0       Right-arm medium
# 46927  25.0       0                    1.0   Left-arm medium-fast
# 33770  25.0       0                    1.0  Right-arm medium-fast
#
#        BATTING_ODIs_Mat  BATTING_ODIs_Inns  BATTING_ODIs_NO  \
# 46998              16.0               16.0              1.0
# 86254              21.0               18.0              5.0
# ...

# %%
pip install kmodes
# Out:
# ...
# WARNING: You are using pip version 20.2; however, version 20.2.3 is available.
# You should consider upgrading via the 'C:\Users\Thanis\Anaconda3\python.exe -m pip install --upgrade pip' command.
# ...

# %%
import numpy as np
from kmodes.kmodes import KModes

# %%
data = np.random.choice(20, (100, 10))

# %%
data
# Out:
# array([[17, 12,  6, 13, 11, 10,  1,  4,  5,  7],
#        [12, 10, 11, 17,  2,  6, 14, 15,  7,  6],
#        [12, 16,  3, 11,  6, 14, 15,  2,  6, 19],
#        [ 4, 12,  8, 16,  2, 17, 15, 15, 13, 11],
#        [ 1,  8, 15, 14, 15,  7,  2, 14, 16, 17],
#        [ 4,  6, 19, 14,  8, 16, 11,  9, 11, 13],
#        [13,  7,  7, 14,  7, 11,  4,  6,  8,  4],
#        [14, 12, 17,  5,  0, 11,  6, 10,  5,  1],
#        [10, 12, 17, 18, 13,  1, 14, 12, 15,  7],
#        [ 2, 13,  3,  9,  4, 11, 15, 15,  4,  9],
#        [15,  3, 15, 10,  1, 19,  0, 14, 13,  1],
#        [ 3, 16,  0,  4,  9,  2,  6, 17,  9, 15],
#        [13,  1,  1,  2, 11,  5,  5, 16, 17,  3],
#        [ 9, 14,  8, 18,  9, 16,  0, 19, 13, 10],
#        [ 9, 10, 16, 16,  6,  4, 18,  0, 15,  5],
#        [11, 16, 17,  7,  8,  4,  8,  0, 16, 15],
#        [ 3, 13, 19, 18,  4,  4, 16,  8, 17, 19],
#        [ 0,  6, 17,  6, 10,  1,  1, 18, 15,  7],
#        [ 8, 17,  5,  1, 18,  0, 17,  5, 17,  5],
# ...

# %%
km = KModes(n_clusters=4, init='Huang', n_init=5, verbose=1)

# %%
clusters = km.fit_predict(data)

# Print the cluster centroids
print(km.cluster_centroids_)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 24, cost: 802.0
# Run 1, iteration: 2/100, moves: 3, cost: 802.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 15, cost: 824.0
# Run 2, iteration: 2/100, moves: 3, cost: 824.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 27, cost: 797.0
# Run 3, iteration: 2/100, moves: 2, cost: 797.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 15, cost: 808.0
# Run 4, iteration: 2/100, moves: 0, cost: 808.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 17, cost: 800.0
# Run 5, iteration: 2/100, moves: 6, cost: 798.0
# Run 5, iteration: 3/100, moves: 1, cost: 798.0
# Best run was number 3
# ...

# %%
km.labels_
# Out:
# array([1, 1, 3, 0, 2, 0, 1, 1, 0, 0, 2, 3, 0, 2, 2, 3, 2, 0, 0, 2, 0, 3,
#        0, 0, 0, 2, 1, 1, 1, 2, 2, 3, 1, 0, 1, 0, 3, 1, 1, 0, 1, 1, 0, 0,
#        1, 2, 0, 0, 0, 0, 3, 2, 0, 3, 0, 1, 0, 2, 0, 0, 2, 1, 0, 3, 0, 2,
#        3, 3, 2, 3, 3, 3, 2, 0, 0, 2, 0, 3, 0, 0, 1, 0, 1, 0, 1, 0, 3, 1,
#        0, 3, 2, 0, 1, 0, 0, 0, 0, 1, 0, 3], dtype=uint16)

# %%
km = KModes(n_clusters=50, init='Huang', n_init=10, verbose=1)

# %%
km.fit(players4)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 344, cost: 38428.0
# Run 1, iteration: 2/100, moves: 111, cost: 38339.0
# Run 1, iteration: 3/100, moves: 28, cost: 38311.0
# Run 1, iteration: 4/100, moves: 7, cost: 38310.0
# Run 1, iteration: 5/100, moves: 0, cost: 38310.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 394, cost: 38365.0
# Run 2, iteration: 2/100, moves: 91, cost: 38328.0
# Run 2, iteration: 3/100, moves: 4, cost: 38322.0
# Run 2, iteration: 4/100, moves: 3, cost: 38320.0
# Run 2, iteration: 5/100, moves: 0, cost: 38320.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 388, cost: 38478.0
# Run 3, iteration: 2/100, moves: 139, cost: 38390.0
# Run 3, iteration: 3/100, moves: 47, cost: 38367.0
# Run 3, iteration: 4/100, moves: 8, cost: 38362.0
# ...

# %%
players1['group'] = km.labels_

# %%
players1.sample(2)
# Out:
#                      NAME      COUNTRY   Died   Age Other  \
# 22047      Brendan Taylor     Zimbabwe  Alive  33.0     0
# 88833  Chandrapaul Hemraj  West Indies  Alive  26.0     0
#
#                                              Major teams   Batting style  \
# 22047  ['Zimbabwe,', 'Chittagong Kings,', 'Lahore Qal...  Right-hand bat
# 88833  ['West Indies,', 'Guyana,', 'Guyana Under-19s,...   Left-hand bat
#
#                 Bowling style  BATTING_ODIs_Mat  BATTING_ODIs_Inns  ...  \
# 22047      Right-arm offbreak             188.0              187.0  ...
# 88833  Slow left-arm orthodox               6.0                6.0  ...
#
#        BOWLING_T20Is_Wkts  BOWLING_T20Is_Ave  BOWLING_T20Is_Econ  \
# 22047                 1.0               17.0                 3.4
# 88833                 0.0                0.0                 0.0
#
#        BOWLING_T20Is_SR  BOWLING_T20Is_4w  BOWLING_T20Is_5w  \
# 22047              30.0               0.0               0.0
# ...

# %%
players1[players1.group == 38]
# Out:
#                      NAME               COUNTRY   Died   Age Other  \
# 1345        Monde Zondeki          South Africa  Alive  37.0     0
# 2123        James Kirtley               England  Alive  44.0     0
# 14192        Ashfaq Ahmed  United Arab Emirates  Alive  34.0     0
# 16042          Nasir Aziz  United Arab Emirates  Alive  33.0     0
# 19935     Mohammad Kashif           Netherlands  Alive  35.0     0
# 20682        Ramesh David                Canada  Alive  44.0     0
# 20684    Damodar Daesrath                Canada  Alive  38.0     0
# 20943        Abdool Samad                Canada  Alive  40.0     0
# 21437  Tafadzwa Kamungozi              Zimbabwe  Alive  32.0     0
# 22047      Brendan Taylor              Zimbabwe  Alive  33.0     0
# 25027      Martin Guptill           New Zealand  Alive  33.0     0
# 25058         Maddy Green           New Zealand  Alive  27.0     0
# 26531        Jeetan Patel           New Zealand  Alive  39.0     0
# ...

# %%
conda install -c conda-forge scrapy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Thanis\Anaconda3
#
#   added / updated specs:
#     - scrapy
#
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     automat-20.2.0             |             py_0          30 KB  conda-forge
#     conda-4.8.4                |   py38h32f6830_2         3.1 MB  conda-forge
#     constantly-15.1.0          |             py_0           9 KB  conda-forge
#     cssselect-1.1.0            |             py_0          18 KB  conda-forge
#     hyperlink-20.0.1           |     pyh9f0ad1d_0          42 KB  conda-forge
#     incremental-17.5.0         |             py_0          14 KB  conda-forge
#     itemadapter-0.1.0          |             py_0          10 KB  conda-forge
# ...

# %%
import scrapy

# %%
scrapy genspider shopclues www.shopclues.com/mobiles-featured-store-4g-smartphone.html
# Out:
#   File "<ipython-input-29-3650e3443fe9>", line 1
#     scrapy genspider shopclues www.shopclues.com/mobiles-featured-store-4g-smartphone.html
#            ^
# SyntaxError: invalid syntax

# %%
import scrapy


class AliexpressTabletsSpider(scrapy.Spider):
    name = 'aliexpress_tablets'
    allowed_domains = ['aliexpress.com']
    start_urls = ['https://www.aliexpress.com/category/200216607/tablets.html',
                 'https://www.aliexpress.com/category/200216607/tablets/2.html?site=glo&g=y&tag=']


    def parse(self, response):

        print("procesing:"+response.url)
        #Extract data using css selectors
        product_name=response.css('.product::text').extract()
        price_range=response.css('.value::text').extract()
        #Extract data using xpath
        orders=response.xpath("//em[@title='Total Orders']/text()").extract()
        company_name=response.xpath("//a[@class='store $p4pLog']/text()").extract()

        row_data=zip(product_name,price_range,orders,company_name)

        #Making extracted data row wise
        for item in row_data:
            #create a dictionary to store the scraped info
            scraped_info = {
                #key:value
                'page':response.url,
                'product_name' : item[0], #item[0] means product in the list and so on, index tells what value to assign
                'price_range' : item[1],
                'orders' : item[2],
                'company_name' : item[3],
            }

            #yield or give the scraped info to scrapy
            yield scraped_info

# %%
import scrapy

class TechcrunchSpider(scrapy.Spider):
    #name of the spider
    name = 'techcrunch'

    #list of allowed domains
    allowed_domains = ['techcrunch.com/feed/']

    #starting url for scraping
    start_urls = ['http://techcrunch.com/feed/']

    #setting the location of the output csv file
    custom_settings = {
        'FEED_URI' : 'tmp/techcrunch.csv'
    }

    def parse(self, response):
        #Remove XML namespaces
        print('<<')
        response.selector.remove_namespaces()

        #Extract article information
        titles = response.xpath('//item/title/text()').extract()
        authors = response.xpath('//item/creator/text()').extract()
        dates = response.xpath('//item/pubDate/text()').extract()
        links = response.xpath('//item/link/text()').extract()

        for item in zip(titles,authors,dates,links):
            scraped_info = {
                'title' : item[0],
                'author' : item[1],
                'publish_date' : item[2],
                'link' : item[3]
            }
            print(scraped_info)

            yield scraped_info

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-da2318c310f4> in <module>
# ----> 1 scraped_info
#
# NameError: name 'scraped_info' is not defined
