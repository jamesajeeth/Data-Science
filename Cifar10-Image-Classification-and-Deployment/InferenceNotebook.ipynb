# %%
from src.inference import Inference

# %%
#pass anyone of the below as attribute to the inference model
#GoogleNet, DenseNet, Resnet50
model_name = 'GoogleNet'
infer = Inference(model_name)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# No of params in model is  6956298
# model is loaded on GPU False

# %%
import PIL
import matplotlib.pyplot as plt
plt.imshow(PIL.Image.open("data/tmp_2240.jpg"))

# %%
infer("data/tmp_2240.jpg")
# Out:
# 'truck'
